# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e96dc35615d362d688c62602aa2e37d4

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + " "
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the tuple() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
#    print(coordinate[0], coordinate[1])

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 635

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# iterate through our list of cities and begin building the URL for each city, while grouping our records in sets of 50 using for i in 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
#  34 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 4 | khorramshahr
# Processing Record 36 of Set 4 | mitsamiouli
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | gushikawa
# Processing Record 39 of Set 4 | vostok
# Processing Record 40 of Set 4 | north bend
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | pacific grove
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | puerto ayora
# Processing Record 45 of Set 4 | chaa-khol
# City not found. Skipping...
# Processing Record 46 of Set 4 | solnechnyy
# Processing Record 47 of Set 4 | mercedes
# Processing Record 48 of Set 4 | boende
# Processing Record 49 of Set 4 | port macquarie
# Processing Record 50 of Set 4 | juneau
# Processing Record 1 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 5 | alyangula
# Processing Record 4 of Set 5 | cockburn town
# Processing Record 5 of Set 5 | ampanihy
# Processing Record 6 of Set 5 | terrace
# Processing Record 7 of Set 5 | ribeira grande
# Processing Record 8 of Set 5 | broome
# Processing Record 9 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | santa maria
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | lodwar
# Processing Record 14 of Set 5 | touros
# Processing Record 15 of Set 5 | nikel
# Processing Record 16 of Set 5 | elat
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | rondonopolis
# Processing Record 20 of Set 5 | daru
# Processing Record 21 of Set 5 | kieta
# Processing Record 22 of Set 5 | klaksvik
# Processing Record 23 of Set 5 | eydhafushi
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | alanya
# Processing Record 26 of Set 5 | berdigestyakh
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | zelenoborskiy
# Processing Record 29 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | nueva italia
# Processing Record 33 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 5 | benghazi
# Processing Record 35 of Set 5 | chisinau
# Processing Record 36 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 5 | monrovia
# Processing Record 38 of Set 5 | mayumba
# Processing Record 39 of Set 5 | la ronge
# Processing Record 40 of Set 5 | mamallapuram
# Processing Record 41 of Set 5 | grindavik
# Processing Record 42 of Set 5 | ust-uda
# Processing Record 43 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 5 | nishihara
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | te anau
# Processing Record 47 of Set 5 | sisimiut
# Processing Record 48 of Set 5 | insar
# Processing Record 49 of Set 5 | rio grande
# Processing Record 50 of Set 5 | nelson bay
# Processing Record 1 of Set 6 | leshukonskoye
# Processing Record 2 of Set 6 | marsa matruh
# Processing Record 3 of Set 6 | severo-kurilsk
# Processing Record 4 of Set 6 | jawhar
# Processing Record 5 of Set 6 | san cristobal
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | ornskoldsvik
# Processing Record 8 of Set 6 | shieli
# Processing Record 9 of Set 6 | rudnogorsk
# Processing Record 10 of Set 6 | pailitas
# Processing Record 11 of Set 6 | harrisonville
# Processing Record 12 of Set 6 | taltal
# Processing Record 13 of Set 6 | hazorasp
# Processing Record 14 of Set 6 | solton
# Processing Record 15 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 6 | pasighat
# Processing Record 17 of Set 6 | ahuimanu
# Processing Record 18 of Set 6 | pevek
# Processing Record 19 of Set 6 | buin
# Processing Record 20 of Set 6 | svrljig
# Processing Record 21 of Set 6 | talara
# Processing Record 22 of Set 6 | bull savanna
# Processing Record 23 of Set 6 | ilulissat
# Processing Record 24 of Set 6 | verkhniy avzyan
# Processing Record 25 of Set 6 | anakapalle
# Processing Record 26 of Set 6 | sao luis do quitunde
# Processing Record 27 of Set 6 | qaqortoq
# Processing Record 28 of Set 6 | senekal
# Processing Record 29 of Set 6 | zeya
# Processing Record 30 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | sur
# Processing Record 33 of Set 6 | puerto el triunfo
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | panzhihua
# Processing Record 36 of Set 6 | obama
# Processing Record 37 of Set 6 | bad wurzach
# Processing Record 38 of Set 6 | wilmington
# Processing Record 39 of Set 6 | lucapa
# Processing Record 40 of Set 6 | izumo
# Processing Record 41 of Set 6 | coquimbo
# Processing Record 42 of Set 6 | zhigalovo
# Processing Record 43 of Set 6 | honningsvag
# Processing Record 44 of Set 6 | takoradi
# Processing Record 45 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 6 | huarmey
# Processing Record 47 of Set 6 | kloulklubed
# Processing Record 48 of Set 6 | gwembe
# Processing Record 49 of Set 6 | gladstone
# Processing Record 50 of Set 6 | opuwo
# Processing Record 1 of Set 7 | stanghelle
# Processing Record 2 of Set 7 | auki
# Processing Record 3 of Set 7 | glendive
# Processing Record 4 of Set 7 | lincoln
# Processing Record 5 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 7 | terra santa
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | preobrazheniye
# Processing Record 9 of Set 7 | lompoc
# Processing Record 10 of Set 7 | meulaboh
# Processing Record 11 of Set 7 | liwale
# Processing Record 12 of Set 7 | maxixe
# Processing Record 13 of Set 7 | lima
# Processing Record 14 of Set 7 | matara
# Processing Record 15 of Set 7 | bam
# Processing Record 16 of Set 7 | beaupre
# Processing Record 17 of Set 7 | srednekolymsk
# Processing Record 18 of Set 7 | kawalu
# Processing Record 19 of Set 7 | ballina
# Processing Record 20 of Set 7 | nakamura
# Processing Record 21 of Set 7 | channel-port aux basques
# Processing Record 22 of Set 7 | maniitsoq
# Processing Record 23 of Set 7 | atagay
# Processing Record 24 of Set 7 | nome
# Processing Record 25 of Set 7 | viedma
# Processing Record 26 of Set 7 | tutoia
# Processing Record 27 of Set 7 | uitenhage
# Processing Record 28 of Set 7 | verkhneyarkeyevo
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | katete
# Processing Record 31 of Set 7 | unye
# City not found. Skipping...
# Processing Record 32 of Set 7 | minnedosa
# Processing Record 33 of Set 7 | bethal
# Processing Record 34 of Set 7 | samokov
# Processing Record 35 of Set 7 | katha
# City not found. Skipping...
# Processing Record 36 of Set 7 | manono
# Processing Record 37 of Set 7 | pundaguitan
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | san
# Processing Record 40 of Set 7 | moose factory
# Processing Record 41 of Set 7 | chino valley
# Processing Record 42 of Set 7 | torrington
# Processing Record 43 of Set 7 | marawi
# Processing Record 44 of Set 7 | kondinskoye
# Processing Record 45 of Set 7 | kapit
# Processing Record 46 of Set 7 | cheremshanka
# Processing Record 47 of Set 7 | punto fijo
# Processing Record 48 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 7 | cotonou
# Processing Record 50 of Set 7 | nhulunbuy
# Processing Record 1 of Set 8 | alexandria
# Processing Record 2 of Set 8 | bereda
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | douglas
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | kaitangata
# Processing Record 8 of Set 8 | minsk
# Processing Record 9 of Set 8 | westport
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | bilma
# Processing Record 12 of Set 8 | puro
# Processing Record 13 of Set 8 | ugoofaaru
# Processing Record 14 of Set 8 | saint-georges
# Processing Record 15 of Set 8 | sao gabriel da cachoeira
# Processing Record 16 of Set 8 | belaya gora
# Processing Record 17 of Set 8 | bambanglipuro
# Processing Record 18 of Set 8 | along
# Processing Record 19 of Set 8 | surman
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | kenai
# Processing Record 22 of Set 8 | stykkisholmur
# Processing Record 23 of Set 8 | luxor
# Processing Record 24 of Set 8 | luderitz
# Processing Record 25 of Set 8 | ughelli
# Processing Record 26 of Set 8 | beaune
# Processing Record 27 of Set 8 | ballitoville
# Processing Record 28 of Set 8 | flin flon
# Processing Record 29 of Set 8 | puerto ayacucho
# Processing Record 30 of Set 8 | zhuhai
# Processing Record 31 of Set 8 | piacabucu
# Processing Record 32 of Set 8 | kedrovyy
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | yatou
# Processing Record 35 of Set 8 | tashara
# Processing Record 36 of Set 8 | severnyy
# Processing Record 37 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 38 of Set 8 | cap malheureux
# Processing Record 39 of Set 8 | oskarshamn
# Processing Record 40 of Set 8 | iqaluit
# Processing Record 41 of Set 8 | pingxiang
# Processing Record 42 of Set 8 | aswan
# Processing Record 43 of Set 8 | gizo
# Processing Record 44 of Set 8 | ambon
# Processing Record 45 of Set 8 | praya
# Processing Record 46 of Set 8 | nazca
# Processing Record 47 of Set 8 | silver city
# Processing Record 48 of Set 8 | le mars
# Processing Record 49 of Set 8 | ouro preto do oeste
# Processing Record 50 of Set 8 | linxia
# Processing Record 1 of Set 9 | tupik
# Processing Record 2 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 3 of Set 9 | nabire
# Processing Record 4 of Set 9 | bandarbeyla
# Processing Record 5 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 9 | iskateley
# Processing Record 7 of Set 9 | talnakh
# Processing Record 8 of Set 9 | roma
# Processing Record 9 of Set 9 | tabou
# Processing Record 10 of Set 9 | betsiamites
# Processing Record 11 of Set 9 | coahuayana
# Processing Record 12 of Set 9 | grootfontein
# Processing Record 13 of Set 9 | hami
# Processing Record 14 of Set 9 | miramar
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | arlit
# Processing Record 17 of Set 9 | waingapu
# Processing Record 18 of Set 9 | balabac
# Processing Record 19 of Set 9 | galveston
# Processing Record 20 of Set 9 | villaviciosa
# Processing Record 21 of Set 9 | port said
# Processing Record 22 of Set 9 | russell
# Processing Record 23 of Set 9 | kasungu
# Processing Record 24 of Set 9 | merauke
# Processing Record 25 of Set 9 | byron bay
# Processing Record 26 of Set 9 | colesberg
# Processing Record 27 of Set 9 | obo
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | dunedin
# Processing Record 31 of Set 9 | wagar
# Processing Record 32 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 9 | jaen
# Processing Record 34 of Set 9 | shabo
# Processing Record 35 of Set 9 | svetlaya
# Processing Record 36 of Set 9 | bihoro
# Processing Record 37 of Set 9 | bowling green
# Processing Record 38 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 9 | damietta
# Processing Record 40 of Set 9 | college
# Processing Record 41 of Set 9 | dimitrovgrad
# Processing Record 42 of Set 9 | vardo
# Processing Record 43 of Set 9 | sao jose da coroa grande
# Processing Record 44 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 9 | binzhou
# Processing Record 46 of Set 9 | manzhouli
# Processing Record 47 of Set 9 | santa engracia
# Processing Record 48 of Set 9 | chuy
# Processing Record 49 of Set 9 | kamenka
# Processing Record 50 of Set 9 | lasa
# Processing Record 1 of Set 10 | harlingen
# Processing Record 2 of Set 10 | grand-santi
# Processing Record 3 of Set 10 | teguise
# Processing Record 4 of Set 10 | tual
# Processing Record 5 of Set 10 | ciudad bolivar
# Processing Record 6 of Set 10 | arti
# Processing Record 7 of Set 10 | nurlat
# Processing Record 8 of Set 10 | mbandaka
# Processing Record 9 of Set 10 | aguada de pasajeros
# Processing Record 10 of Set 10 | xiangfan
# Processing Record 11 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 12 of Set 10 | samarai
# Processing Record 13 of Set 10 | timizart
# Processing Record 14 of Set 10 | hamilton
# Processing Record 15 of Set 10 | union hidalgo
# Processing Record 16 of Set 10 | basse-pointe
# Processing Record 17 of Set 10 | kulhudhuffushi
# Processing Record 18 of Set 10 | provideniya
# Processing Record 19 of Set 10 | barra do garcas
# Processing Record 20 of Set 10 | saint-pierre
# Processing Record 21 of Set 10 | port elizabeth
# Processing Record 22 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 10 | barra patuca
# Processing Record 24 of Set 10 | san ramon
# Processing Record 25 of Set 10 | olafsvik
# Processing Record 26 of Set 10 | broken hill
# Processing Record 27 of Set 10 | bhola
# Processing Record 28 of Set 10 | lokomotivnyy
# Processing Record 29 of Set 10 | garowe
# Processing Record 30 of Set 10 | kimbe
# Processing Record 31 of Set 10 | gazanjyk
# Processing Record 32 of Set 10 | gamba
# Processing Record 33 of Set 10 | lingao
# Processing Record 34 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 10 | moron
# Processing Record 36 of Set 10 | groningen
# Processing Record 37 of Set 10 | luba
# Processing Record 38 of Set 10 | tuatapere
# Processing Record 39 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 40 of Set 10 | prince rupert
# Processing Record 41 of Set 10 | iglino
# Processing Record 42 of Set 10 | zhaotong
# Processing Record 43 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 44 of Set 10 | castres
# Processing Record 45 of Set 10 | san andres
# Processing Record 46 of Set 10 | ambunti
# Processing Record 47 of Set 10 | tyrma
# Processing Record 48 of Set 10 | nueve de julio
# Processing Record 49 of Set 10 | digby
# Processing Record 50 of Set 10 | teeli
# Processing Record 1 of Set 11 | salym
# Processing Record 2 of Set 11 | ostrovnoy
# Processing Record 3 of Set 11 | havelock
# Processing Record 4 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 11 | caravelas
# Processing Record 6 of Set 11 | antalaha
# Processing Record 7 of Set 11 | neuquen
# Processing Record 8 of Set 11 | naze
# Processing Record 9 of Set 11 | anjiang
# Processing Record 10 of Set 11 | hay river
# Processing Record 11 of Set 11 | otradnoye
# Processing Record 12 of Set 11 | fayaoue
# Processing Record 13 of Set 11 | flinders
# Processing Record 14 of Set 11 | kretinga
# Processing Record 15 of Set 11 | ondjiva
# Processing Record 16 of Set 11 | tarko-sale
# Processing Record 17 of Set 11 | clyde river
# Processing Record 18 of Set 11 | thyboron
# Processing Record 19 of Set 11 | bathsheba
# Processing Record 20 of Set 11 | tautira
# Processing Record 21 of Set 11 | jacmel
# Processing Record 22 of Set 11 | makakilo city
# Processing Record 23 of Set 11 | torrox
# Processing Record 24 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 11 | kudahuvadhoo
# Processing Record 26 of Set 11 | loiza
# Processing Record 27 of Set 11 | slanic-moldova
# Processing Record 28 of Set 11 | fairbanks
# Processing Record 29 of Set 11 | sabha
# Processing Record 30 of Set 11 | ponta delgada
# Processing Record 31 of Set 11 | kilindoni
# Processing Record 32 of Set 11 | theux
# Processing Record 33 of Set 11 | malakal
# Processing Record 34 of Set 11 | perth
# Processing Record 35 of Set 11 | kailua
# Processing Record 36 of Set 11 | xucheng
# Processing Record 37 of Set 11 | bhilai
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | hirara
# Processing Record 40 of Set 11 | guerrero negro
# Processing Record 41 of Set 11 | kidal
# Processing Record 42 of Set 11 | shitanjing
# Processing Record 43 of Set 11 | marica
# Processing Record 44 of Set 11 | cozumel
# Processing Record 45 of Set 11 | changli
# Processing Record 46 of Set 11 | kuala terengganu
# Processing Record 47 of Set 11 | nueva granada
# Processing Record 48 of Set 11 | gat
# Processing Record 49 of Set 11 | sitka
# Processing Record 50 of Set 11 | vila franca do campo
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | agadez
# Processing Record 3 of Set 12 | beloomut
# Processing Record 4 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 5 of Set 12 | illkirch-graffenstaden
# Processing Record 6 of Set 12 | abancay
# Processing Record 7 of Set 12 | myitkyina
# Processing Record 8 of Set 12 | mayo
# Processing Record 9 of Set 12 | shar
# Processing Record 10 of Set 12 | kem
# Processing Record 11 of Set 12 | paciran
# Processing Record 12 of Set 12 | catamarca
# Processing Record 13 of Set 12 | hlobyne
# Processing Record 14 of Set 12 | dryden
# Processing Record 15 of Set 12 | port lincoln
# Processing Record 16 of Set 12 | mount gambier
# Processing Record 17 of Set 12 | were ilu
# Processing Record 18 of Set 12 | hicaque
# Processing Record 19 of Set 12 | maba
# Processing Record 20 of Set 12 | antibes
# Processing Record 21 of Set 12 | gobabis
# Processing Record 22 of Set 12 | limon
# Processing Record 23 of Set 12 | kirkwall
# Processing Record 24 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 12 | mormugao
# Processing Record 26 of Set 12 | labrea
# Processing Record 27 of Set 12 | atar
# Processing Record 28 of Set 12 | talesh
# City not found. Skipping...
# Processing Record 29 of Set 12 | cervo
# Processing Record 30 of Set 12 | sarangani
# Processing Record 31 of Set 12 | limulunga
# Processing Record 32 of Set 12 | waiouru
# Processing Record 33 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 12 | rovaniemi
# Processing Record 35 of Set 12 | aasiaat
# Processing Record 36 of Set 12 | muromtsevo
# Processing Record 37 of Set 12 | san patricio
# Processing Record 38 of Set 12 | bonnyville
# Processing Record 39 of Set 12 | mount isa
# Processing Record 40 of Set 12 | seoni malwa
# Processing Record 41 of Set 12 | payo
# Processing Record 42 of Set 12 | swidnica
# Processing Record 43 of Set 12 | biloela
# Processing Record 44 of Set 12 | lakatoro
# Processing Record 45 of Set 12 | chokwe
# Processing Record 46 of Set 12 | tura
# Processing Record 47 of Set 12 | richards bay
# Processing Record 48 of Set 12 | biak
# Processing Record 49 of Set 12 | venezuela
# Processing Record 50 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 1 of Set 13 | port-gentil
# Processing Record 2 of Set 13 | brae
# Processing Record 3 of Set 13 | pontes e lacerda
# Processing Record 4 of Set 13 | maraba
# Processing Record 5 of Set 13 | san policarpo
# Processing Record 6 of Set 13 | srandakan
# Processing Record 7 of Set 13 | carhuamayo
# Processing Record 8 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 13 | hovd
# Processing Record 10 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 13 | lingdong
# Processing Record 12 of Set 13 | sept-iles
# Processing Record 13 of Set 13 | lahaina
# Processing Record 14 of Set 13 | teahupoo
# Processing Record 15 of Set 13 | bhiwani
# Processing Record 16 of Set 13 | marale
# Processing Record 17 of Set 13 | butembo
# Processing Record 18 of Set 13 | lazaro cardenas
# Processing Record 19 of Set 13 | brantford
# Processing Record 20 of Set 13 | yandoon
# City not found. Skipping...
# Processing Record 21 of Set 13 | mporokoso
# Processing Record 22 of Set 13 | kayes
# Processing Record 23 of Set 13 | beshpagir
# Processing Record 24 of Set 13 | sri aman
# Processing Record 25 of Set 13 | andenes
# Processing Record 26 of Set 13 | acapulco
# Processing Record 27 of Set 13 | haimen
# Processing Record 28 of Set 13 | gueret
# Processing Record 29 of Set 13 | napier
# Processing Record 30 of Set 13 | tomatlan
# Processing Record 31 of Set 13 | anadyr
# Processing Record 32 of Set 13 | alta floresta
# Processing Record 33 of Set 13 | whitehorse
# Processing Record 34 of Set 13 | zafarwal
# Processing Record 35 of Set 13 | inhambane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kahului  20.8947 -156.4700     78.84        77          13        5.01
# 1       Xining  36.6167  101.7667     53.40        58          41        3.89
# 2      Ushuaia -54.8000  -68.3000     29.86        93          90        8.05
# 3    Abu Dhabi  24.4667   54.3667     91.51        66           0        8.59
# 4     Victoria  22.2855  114.1577     86.97        88         100        1.99
# 5     Bilibino  68.0546  166.4372     45.25        60          67        1.72
# 6  Wapi Pathum  15.8452  103.3768     86.99        74          84        9.57
# 7        Bluff -46.6000  168.3333     49.80        86         100       19.48
# 8       Albany  42.6001  -73.9662     50.72        83         100        3.74
# 9      Mataura -46.1927  168.8643     49.48        96         100        4.27
#
#   Country                 Date
# 0      US  2021-05-29 17:54:25
# 1      CN  2021-05-29 17:54:25
# 2      AR  2021-05-29 17:52:00
# 3      AE  2021-05-29 17:51:37
# 4      HK  2021-05-29 17:49:33
# 5      RU  2021-05-29 17:51:08
# 6      TH  2021-05-29 17:54:25
# 7      NZ  2021-05-29 17:53:35
# 8      US  2021-05-29 17:52:03
# 9      NZ  2021-05-29 17:54:26

# %%
new_column_order = ["column2", "column4", "column1"]
city_data_dfe = city_data_df[new_column_order]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-233275aa9242> in <module>
#       1 new_column_order = ["column2", "column4", "column1"]
# ----> 2 city_data_dfe = city_data_df[new_column_order]
#
# C:\Python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\Python\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\Python\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['column2', 'column4', 'column1'], dtype='object')] are in the [columns]"

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-d018e8067549> in <module>
#       2 output_data_file = "weather_data/cities.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# C:\Python\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# C:\Python\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# C:\Python\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# C:\Python\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/cities.csv'
